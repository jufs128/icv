# %%
import cv2
import numpy as np
import sys
import matplotlib as plt
import sklearn
import torch

# %%
img = cv2.imread('jhope.jpg', cv2.IMREAD_COLOR)

# %%
print(img.shape)
# Out:
# (479, 640, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
from matplotlib import pyplot as plt

plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
flattered_image = img.ravel()

# %%
flattered_image.shape
# Out:
# (919680,)

# %%
plt.hist(flattered_image, 256, [0,255])
plt.xlim([0,255])
plt.show()

# %%
cv2.imwrite('jhope.png', img)
# Out:
# True
